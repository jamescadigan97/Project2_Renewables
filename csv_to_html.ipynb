# %%
import pandas as pd
import numpy as np

# %%
all_fuels = "./Resources/all_fuels.csv"
all_fuels_df = pd.read_csv(all_fuels)
all_fuels_df
# Out:
#                             description                   units  \
# 0           All sectors : United States  thousand megawatthours
# 1             All sectors : New England                     NaN
# 2             All sectors : Connecticut  thousand megawatthours
# 3                   All sectors : Maine  thousand megawatthours
# 4           All sectors : Massachusetts  thousand megawatthours
# ..                                  ...                     ...
# 57                 All sectors : Oregon  thousand megawatthours
# 58             All sectors : Washington  thousand megawatthours
# 59  All sectors : Pacific Noncontiguous                     NaN
# 60                 All sectors : Alaska  thousand megawatthours
# 61                 All sectors : Hawaii  thousand megawatthours
#
#                source key       2001       2002       2003       2004  \
# 0    ELEC.GEN.ALL-US-99.A  3736644.0  3858452.0  3883185.0  3970555.0
# ...

# %%
all_fuels_df = all_fuels_df.set_index('description')

# %%
all_fuels_df.to_html("data.html", bold_rows=False)
